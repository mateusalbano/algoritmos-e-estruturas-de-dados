# %% [markdown]
# > # Teste
# > *ArrayList*

# %% [markdown]
# Imports

# %%
import random
from array_list import ArrayList

# %% [markdown]
# Instanciando ArrayList

# %%
list = ArrayList()
print(list)
# Out:
# []

# %% [markdown]
# Método `push_back()`

# %%
list.push_back(1)
list.push_back(2)
list.push_back(3)
list.push_back(4)
list.push_back(5)

print(list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `insert_at()`

# %%
list.insert_at(1, 1.5)
list.insert_at(3, 2.5)
list.insert_at(7, 6)

print(list)
# Out:
# [1, 1.5, 2, 2.5, 3, 4, 5, 6]

# %% [markdown]
# Método `remove_at()`

# %%
list.remove_at(1)
list.remove_at(3)
list.remove_at(5)

print(list)
# Out:
# [1, 2, 2.5, 4, 5]

# %% [markdown]
# Método `pop_back()`

# %%
for _ in range(len(list)):
    print(list.pop_back())
# Out:
# 5
# 4
# 2.5
# 2
# 1

# %% [markdown]
# Método `sort()`

# %%
for _ in range(20):
    list.push_back(random.randint(0,100))

print("Lista desordenada:", list)

list.sort()

print("Lista ordenada:", list)
# Out:
# Lista desordenada: [18, 62, 19, 41, 20, 42, 94, 1, 64, 69, 9, 0, 35, 58, 95, 11, 17, 60, 6, 94]
# Lista ordenada: [0, 1, 6, 9, 11, 17, 18, 19, 20, 35, 41, 42, 58, 60, 62, 64, 69, 94, 94, 95]
