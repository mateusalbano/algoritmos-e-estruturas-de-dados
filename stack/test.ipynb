# %% [markdown]
# > # Teste
# > *Stack e Min Stack*

# %% [markdown]
# Imports

# %%
import sys
import os

caminho_atual = os.getcwd() + "\\.."
sys.path.insert(0, caminho_atual)

from stack.stack import Stack
from stack.min_stack import MinStack
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from stack.stack import Stack
#       2 from stack.min_stack import MinStack
#       3 import random
#
# ModuleNotFoundError: No module named 'stack.stack'; 'stack' is not a package

# %% [markdown]
# Instanciando stack

# %%
stack = Stack()
print(stack)
# Out:
# []

# %% [markdown]
# Método `push()`

# %%
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)

print(stack)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `pop()`

# %%
for _ in range(len(stack)):
    print(stack.pop())
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Instanciando MinStack

# %%
stack = MinStack()

# %% [markdown]
# Método `push()`

# %%
for _ in range(15):
    stack.push(random.randint(0,100))
print(stack)
# Out:
# [85, 100, 9, 9, 98, 56, 1, 42, 28, 17, 24, 48, 25, 36, 2]

# %% [markdown]
# Método `min()` e `pop()`

# %%
for _ in range(len(stack)):
    print("min():", stack.min(), "pop():", stack.pop())
# Out:
# min(): 1 pop(): 2
# min(): 1 pop(): 36
# min(): 1 pop(): 25
# min(): 1 pop(): 48
# min(): 1 pop(): 24
# min(): 1 pop(): 17
# min(): 1 pop(): 28
# min(): 1 pop(): 42
# min(): 1 pop(): 1
# min(): 9 pop(): 56
# min(): 9 pop(): 98
# min(): 9 pop(): 9
# min(): 9 pop(): 9
# min(): 85 pop(): 100
# min(): 85 pop(): 85
