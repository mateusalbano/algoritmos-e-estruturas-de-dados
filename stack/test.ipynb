# %% [markdown]
# > # Teste
# > *Stack e Min Stack*

# %% [markdown]
# Imports

# %%
import sys
import os

caminho_atual = os.getcwd() + "\\.."
sys.path.insert(0, caminho_atual)

from stack.stack import Stack
from stack.min_stack import MinStack
import random

# %% [markdown]
# Instanciando stack

# %%
stack = Stack()
print(stack)
# Out:
# []

# %% [markdown]
# Método `push()`

# %%
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)

print(stack)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# Método `pop()`

# %%
for _ in range(len(stack)):
    print(stack.pop())
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Instanciando MinStack

# %%
stack = MinStack()

# %% [markdown]
# Método `push()`

# %%
for _ in range(15):
    stack.push(random.randint(0,100))
print(stack)
# Out:
# [90, 12, 74, 39, 3, 20, 90, 54, 24, 33, 99, 16, 78, 58, 74]

# %% [markdown]
# Método `min()` e `pop()`

# %%
for _ in range(len(stack)):
    print("min():", stack.min(), "pop():", stack.pop())
# Out:
# min(): 3 pop(): 90
# min(): 3 pop(): 12
# min(): 3 pop(): 74
# min(): 3 pop(): 39
# min(): 3 pop(): 3
# min(): 16 pop(): 20
# min(): 16 pop(): 90
# min(): 16 pop(): 54
# min(): 16 pop(): 24
# min(): 16 pop(): 33
# min(): 16 pop(): 99
# min(): 16 pop(): 16
# min(): 58 pop(): 78
# min(): 58 pop(): 58
# min(): 74 pop(): 74
