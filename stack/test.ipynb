# %% [markdown]
# > # Teste
# > *Stack e Min Stack*

# %% [markdown]
# Imports

# %%
import sys
import os

caminho_atual = os.getcwd() + "\\.."
sys.path.insert(0, caminho_atual)

from stack.stack import Stack
from stack.min_stack import MinStack
import random

# %% [markdown]
# Instanciando stack

# %%
stack = Stack()
print(stack)
# Out:
# []

# %% [markdown]
# Método `push()`

# %%
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)

print(stack)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `pop()`

# %%
for _ in range(len(stack)):
    print(stack.pop())
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Instanciando MinStack

# %%
stack = MinStack()

# %% [markdown]
# Método `push()`

# %%
for _ in range(15):
    stack.push(random.randint(0,100))
print(stack)
# Out:
# [27, 15, 87, 45, 43, 15, 16, 97, 97, 19, 79, 21, 95, 3, 11]

# %% [markdown]
# Método `min()` e `pop()`

# %%
for _ in range(len(stack)):
    print("min():", stack.min(), "pop():", stack.pop())
# Out:
# min(): 3 pop(): 11
# min(): 3 pop(): 3
# min(): 15 pop(): 95
# min(): 15 pop(): 21
# min(): 15 pop(): 79
# min(): 15 pop(): 19
# min(): 15 pop(): 97
# min(): 15 pop(): 97
# min(): 15 pop(): 16
# min(): 15 pop(): 15
# min(): 15 pop(): 43
# min(): 15 pop(): 45
# min(): 15 pop(): 87
# min(): 15 pop(): 15
# min(): 27 pop(): 27
