# %% [markdown]
# > # Teste
# > *Stack e Min Stack*

# %% [markdown]
# Imports

# %%
import sys
import os

caminho_atual = os.getcwd() + "\\.."
sys.path.insert(0, caminho_atual)

from stack.stack import Stack
from stack.min_stack import MinStack
import random

# %% [markdown]
# Instanciando stack

# %%
stack = Stack()
print(stack)
# Out:
# []

# %% [markdown]
# Método `push()`

# %%
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(4)
stack.push(5)

print(stack)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `pop()`

# %%
for _ in range(len(stack)):
    print(stack.pop())
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# Instanciando MinStack

# %%
stack = MinStack()

# %% [markdown]
# Método `push()`

# %%
for _ in range(15):
    stack.push(random.randint(0,100))
print(stack)
# Out:
# [48, 81, 16, 32, 46, 85, 91, 75, 55, 5, 66, 29, 16, 9, 16]

# %% [markdown]
# Método `min()` e `pop()`

# %%
for _ in range(len(stack)):
    print("min():", stack.min(), "pop():", stack.pop())
# Out:
# min(): 5 pop(): 16
# min(): 5 pop(): 9
# min(): 5 pop(): 16
# min(): 5 pop(): 29
# min(): 5 pop(): 66
# min(): 5 pop(): 5
# min(): 16 pop(): 55
# min(): 16 pop(): 75
# min(): 16 pop(): 91
# min(): 16 pop(): 85
# min(): 16 pop(): 46
# min(): 16 pop(): 32
# min(): 16 pop(): 16
# min(): 48 pop(): 81
# min(): 48 pop(): 48
