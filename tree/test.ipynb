# %% [markdown]
# > # Teste
# > *BinaryTree*

# %% [markdown]
# Imports

# %%
import random
from binary_tree import BinaryTree

# %% [markdown]
# Instanciando BinaryTree

# %%
binary_tree = BinaryTree()

# %% [markdown]
# Método `insert()`

# %%
for _ in range(0, 20):
    binary_tree.insert(random.randint(0, 100))

# pré-ordem
print(binary_tree)
# Out:
# [16, 11, 5, 1, 5, 4, 2, 7, 25, 81, 64, 62, 47, 44, 29, 60, 65, 65, 89, 84]

# %% [markdown]
# Método `contains()`

# %%
n = random.randint(0, 100)
print("n:", n)
print("contains(n):", binary_tree.contains(n))
# Out:
# n: 38
# contains(n): False

# %% [markdown]
# Método `preorder_traversal()`

# %%
print(binary_tree.preorder_traversal())
# Out:
# [16, 11, 5, 1, 5, 4, 2, 7, 25, 81, 64, 62, 47, 44, 29, 60, 65, 65, 89, 84]

# %% [markdown]
# Método `inorder_traversal()`

# %%
print(binary_tree.inorder_traversal())
# Out:
# [1, 2, 4, 5, 5, 7, 11, 16, 25, 29, 44, 47, 60, 62, 64, 65, 65, 81, 84, 89]

# %% [markdown]
# Método `postorder_traversal()`

# %%
print(binary_tree.postorder_traversal())
# Out:
# [2, 4, 5, 1, 7, 5, 11, 29, 44, 60, 47, 62, 65, 65, 64, 84, 89, 81, 25, 16]
