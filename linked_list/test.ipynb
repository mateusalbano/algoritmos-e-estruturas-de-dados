# %% [markdown]
# > # Teste
# > *LinkedList e DoublyLinkedList*

# %% [markdown]
# Imports

# %%
import random
from linked_list import LinkedList
from doubly_linked_list import DoublyLinkedList

# %% [markdown]
# Instanciando LinkedList

# %%
list = LinkedList()
print(list)
# Out:
# []

# %% [markdown]
# Método `push_back()`

# %%
list.push_back(1)
list.push_back(2)
list.push_back(3)
list.push_back(4)
list.push_back(5)

print(list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `push_front()`

# %%
list.push_front(1)
list.push_front(2)
list.push_front(3)
list.push_front(4)
list.push_front(5)

print(list)
# Out:
# [5, 4, 3, 2, 1, 1, 2, 3, 4, 5]

# %% [markdown]
# Método `pop_back()`

# %%
list.pop_back()
print(list)
# Out:
# [5, 4, 3, 2, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `pop_front()`

# %%
list.pop_front()
print(list)
# Out:
# [4, 3, 2, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `insert_at()`

# %%
list.insert_at(1, 1.5)
list.insert_at(3, 2.5)
list.insert_at(7, 6)

print(list)
# Out:
# [4, 1.5, 3, 2.5, 2, 1, 1, 6, 2, 3, 4]

# %% [markdown]
# Método `remove_at()`

# %%
list.remove_at(1)
list.remove_at(3)
list.remove_at(5)

print(list)
# Out:
# [4, 3, 2.5, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `sort()`

# %%
for _ in range(20):
    list.push_back(random.randint(0,100))

print("Lista desordenada:", list)

list.sort()

print("Lista ordenada:", list)
# Out:
# Lista desordenada: [4, 3, 2.5, 1, 1, 2, 3, 4, 58, 91, 55, 98, 14, 61, 36, 41, 74, 18, 55, 86, 88, 97, 16, 68, 57, 61, 46, 44]
# Lista ordenada: [1, 1, 2, 2.5, 3, 3, 4, 4, 14, 16, 18, 36, 41, 44, 46, 55, 55, 57, 58, 61, 61, 68, 74, 86, 88, 91, 97, 98]

# %% [markdown]
# Instanciando DoublyLinkedList

# %%
list = DoublyLinkedList()
print(list)
# Out:
# []

# %% [markdown]
# Método `push_back()`

# %%
list.push_back(1)
list.push_back(2)
list.push_back(3)
list.push_back(4)
list.push_back(5)

print(list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Método `push_front()`

# %%
list.push_front(1)
list.push_front(2)
list.push_front(3)
list.push_front(4)
list.push_front(5)

print(list)
# Out:
# [5, 4, 3, 2, 1, 1, 2, 3, 4, 5]

# %% [markdown]
# Método `pop_back()`

# %%
list.pop_back()
print(list)
# Out:
# [5, 4, 3, 2, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `pop_front()`

# %%
list.pop_front()
print(list)
# Out:
# [4, 3, 2, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `insert_at()`

# %%
list.insert_at(1, 1.5)
list.insert_at(3, 2.5)
list.insert_at(7, 6)

print(list)
# Out:
# [4, 1.5, 3, 2.5, 2, 1, 1, 6, 2, 3, 4]

# %% [markdown]
# Método `remove_at()`

# %%
list.remove_at(1)
list.remove_at(3)
list.remove_at(5)

print(list)
# Out:
# [4, 3, 2.5, 1, 1, 2, 3, 4]

# %% [markdown]
# Método `sort()`

# %%
for _ in range(20):
    list.push_back(random.randint(0,100))

print("Lista desordenada:", list)

list.sort()

print("Lista ordenada:", list)
# Out:
# Lista desordenada: [4, 3, 2.5, 1, 1, 2, 3, 4, 52, 32, 19, 91, 95, 31, 9, 37, 73, 52, 100, 76, 10, 16, 80, 49, 95, 47, 80, 67]
# Lista ordenada: [1, 1, 2, 2.5, 3, 3, 4, 4, 9, 10, 16, 19, 31, 32, 37, 47, 49, 52, 52, 67, 73, 76, 80, 80, 91, 95, 95, 100]
